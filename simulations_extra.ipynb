# %%
import numpy as np
import pandas as pd
import pickle
from tqdm import tqdm
import matplotlib.pyplot as plt

from check_warmup import avg_warmup_count, plot_avg_warmup_count

from environment import GLMBandit

from glmbanditexp.algorithms.ecolog import EcoLog
from glmbanditexp.algorithms.gloc import Gloc
from glmbanditexp.algorithms.glm_ucb import GlmUCB
from glmbanditexp.algorithms.rs_glinucb import RS_GLinUCB
from glmbanditexp.algorithms.private_rs_glinucb import Private_RS_GLinUCB
from glmbanditexp.algorithms.ofulogplus import OFULogPlus

# Import simulation utilities
from simulation_utils import simulate_with_epsilon, plot_regret

# %%
num_trials = 10
d=5
K=10
T=5000
kappa=50.0
R=1.0
S=5.0
lmbda=20.0
seed=186329

# %%
count = avg_warmup_count(num_trials, d, K, T, kappa, R, S, lmbda, seed)
plot_avg_warmup_count(count, show_flag=True)
# Out:
# Running trial 1
# 100%|██████████| 5000/5000 [00:00<00:00, 13101.89it/s]
# Running trial 2
# 100%|██████████| 5000/5000 [00:00<00:00, 10763.67it/s]
# Running trial 3
# 100%|██████████| 5000/5000 [00:00<00:00, 14693.17it/s]
# Running trial 4
# 100%|██████████| 5000/5000 [00:00<00:00, 14163.94it/s]
# Running trial 5
# 100%|██████████| 5000/5000 [00:00<00:00, 11626.58it/s]
# Running trial 6
# 100%|██████████| 5000/5000 [00:00<00:00, 14734.65it/s]
# Running trial 7
# 100%|██████████| 5000/5000 [00:00<00:00, 15755.12it/s]
# Running trial 8
# 100%|██████████| 5000/5000 [00:00<00:00, 14710.17it/s]
# Running trial 9
# 100%|██████████| 5000/5000 [00:00<00:00, 14627.55it/s]
# Running trial 10
# 100%|██████████| 5000/5000 [00:00<00:00, 15214.00it/s]

# %%
config = {"full_norm": True}
config['seed'] = 109832
config['model'] = 'Logistic'
config['theta_dim'] = 3
config['num_arms'] = 20
config['theta_norm'] = 2.5
config['horizon_length'] = 10000

env = GLMBandit(config=config)
print('Kappa =', env.kappa)
print('Theta =' , env.theta)
# Out:
# Calculating kappa...
# 100%|██████████| 10000/10000 [00:00<00:00, 22129.51it/s]
# Calculating kappa star...
# 100%|██████████| 10000/10000 [00:00<00:00, 48388.87it/s]
# Kappa = 14.226649648734286
# Theta = [0.36927006 2.28323855 0.94892641]

# %%
algo_names_list = ['RS-GLinUCB', 'EcoLog', 'GLOC', 'Private-GLM']
num_trials = 10

regret_dict = simulate_with_epsilon(num_trials, env, algo_names_list, 0.02, epsilon_arr = [4, 6,8], seed=109832)
with open('./Results/Extras/experiment_logistic_uniform_split_S_2_5.pickle', 'wb') as f:
    pickle.dump(regret_dict, f)
plot_regret(regret_dict, env.T, './Results/Extras/Logistic_Regret_S_2_5.png')
##plot_regret(regret_dict, env.T, './Results/Logistic_Regret.png')
# Out:
# Simulating trial 1
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2041/10000 [00:14<00:50, 158.19it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2072/10000 [00:17<06:03, 21.84it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4113/10000 [00:34<04:00, 24.44it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
#  96%|█████████▌| 9615/10000 [01:13<00:03, 97.85it/s] /Users/sahasrajitsarmasarkar/Downloads/AiStats_appendix/Code/glmbanditexp/algorithms/ecolog.py:123: RuntimeWarning: invalid value encountered in sqrt
#   self.conf_radius = np.sqrt(res_square)
# 100%|██████████| 10000/10000 [01:16<00:00, 130.47it/s]
# Max det curr H: 54669975.95766568, Max det prev H: 50730193.20871624 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34076961.32659247, Max det prev H: 11106989.28105987 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 28288132.24418459, Max det prev H: 8477371.718204051 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 2
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2041/10000 [00:15<00:51, 155.39it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2074/10000 [00:18<05:43, 23.10it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4118/10000 [00:36<06:00, 16.31it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:17<00:00, 128.46it/s]
# Max det curr H: 56076271.12487478, Max det prev H: 50425102.94659972 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 36659698.540835276, Max det prev H: 12630934.904625518 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26967587.67295299, Max det prev H: 8568284.785525113 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 3
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2035/10000 [00:15<00:54, 146.82it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2063/10000 [00:18<07:07, 18.58it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  23%|██▎       | 2253/10000 [00:21<04:27, 28.95it/s]
# Counter2: 2 == 2, crossing at 2237 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:17<00:00, 129.57it/s]
# Max det curr H: 56019480.130950294, Max det prev H: 22293052.35050639 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35554179.15544117, Max det prev H: 11598852.70523512 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27223665.13242662, Max det prev H: 7368495.128722464 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 4
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2037/10000 [00:16<00:50, 156.42it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2067/10000 [00:19<06:09, 21.46it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4114/10000 [00:38<05:31, 17.74it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:25<00:00, 116.30it/s]
# Max det curr H: 56126431.91163023, Max det prev H: 49410999.41935543 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35990795.24243534, Max det prev H: 11392225.688307187 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27273226.315120343, Max det prev H: 8206841.655748663 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 5
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2038/10000 [00:15<00:51, 154.70it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2071/10000 [00:18<06:09, 21.44it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  32%|███▏      | 3201/10000 [00:30<06:49, 16.59it/s]
# Counter2: 2 == 2, crossing at 3186 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:21<00:00, 122.01it/s]
# Max det curr H: 56311570.874023534, Max det prev H: 25060603.073241696 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 36224251.26177469, Max det prev H: 11894654.755422013 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27399725.75891518, Max det prev H: 8604395.698417228 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 6
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2034/10000 [00:14<00:50, 156.42it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2062/10000 [00:17<06:00, 22.02it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4114/10000 [00:39<05:47, 16.91it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:26<00:00, 115.90it/s]
# Max det curr H: 56681312.555420704, Max det prev H: 48179555.62788682 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34388080.392457776, Max det prev H: 11632133.191963984 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27678451.64801789, Max det prev H: 8521191.086497195 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 7
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2043/10000 [00:18<01:11, 111.37it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2070/10000 [00:22<08:03, 16.40it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4119/10000 [00:42<05:10, 18.95it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:32<00:00, 107.80it/s]
# Max det curr H: 54775957.79952881, Max det prev H: 48013054.27143838 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35389286.13925809, Max det prev H: 11377554.894342428 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27462537.525679193, Max det prev H: 7603953.548799027 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 8
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2036/10000 [00:16<00:56, 142.15it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  21%|██        | 2066/10000 [00:21<08:36, 15.35it/s]
# Counter2: 2 == 2, crossing at 2051 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:26<00:00, 115.06it/s]
# Max det curr H: 55079081.65269551, Max det prev H: 24328280.69946485 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34491240.85629223, Max det prev H: 11262984.891618615 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 28504433.441567708, Max det prev H: 8131577.9433493335 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 9
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2049/10000 [00:18<00:56, 139.77it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2064/10000 [00:21<09:04, 14.57it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4118/10000 [00:39<04:17, 22.86it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:32<00:00, 108.42it/s]
# Max det curr H: 56917745.099838845, Max det prev H: 48947026.29770722 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34579752.45970446, Max det prev H: 11279679.53647522 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27437748.493720546, Max det prev H: 8536338.236978337 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 10
# Lambda: 172.05721683454195 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 125.58630452692111 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Lambda: 102.35084837311072 private rs glinucb
# Count1 cutoff: 4, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2045/10000 [00:23<01:44, 76.42it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2064/10000 [00:28<14:30,  9.12it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4105/10000 [00:55<10:40,  9.20it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [02:05<00:00, 79.52it/s]
# Max det curr H: 55025452.29323514, Max det prev H: 49230922.163028754 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34849497.771584384, Max det prev H: 11889999.800144818 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27949931.375013072, Max det prev H: 8010677.709411717 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02

# %%
config = {"full_norm": True}
config['seed'] = 109832
config['model'] = 'Logistic'
config['theta_dim'] = 3
config['num_arms'] = 20
config['theta_norm'] = 3.0
config['horizon_length'] = 10000

env = GLMBandit(config=config)
print('Kappa =', env.kappa)
print('Theta =' , env.theta)
# Out:
# Calculating kappa...
# 100%|██████████| 10000/10000 [00:00<00:00, 38813.72it/s]
# Calculating kappa star...
# 100%|██████████| 10000/10000 [00:00<00:00, 38900.37it/s]
# Kappa = 22.059983115115628
# Theta = [0.44312407 2.73988626 1.13871169]

# %%
algo_names_list = ['RS-GLinUCB', 'EcoLog', 'GLOC', 'Private-GLM']
num_trials = 10

regret_dict = simulate_with_epsilon(num_trials, env, algo_names_list, 0.02, epsilon_arr = [4, 6,8], seed=109832)
with open('./Results/Extras/experiment_logistic_uniform_split_S_3_0.pickle', 'wb') as f:
    pickle.dump(regret_dict, f)
plot_regret(regret_dict, env.T, './Results/Extras/Logistic_Regret_S_3_0.png')
##plot_regret(regret_dict, env.T, './Results/Logistic_Regret.png')
# Out:
# Simulating trial 1
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2043/10000 [00:22<01:18, 100.92it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2063/10000 [00:26<11:27, 11.55it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4110/10000 [00:52<09:24, 10.43it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [02:02<00:00, 81.89it/s]
# Max det curr H: 54435349.75177553, Max det prev H: 50539150.45119912 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34154684.82524763, Max det prev H: 11049680.079742983 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26818694.624328934, Max det prev H: 8398664.789806802 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 2
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2039/10000 [00:24<01:13, 107.78it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2060/10000 [00:28<10:25, 12.70it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4110/10000 [00:54<08:15, 11.90it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:59<00:00, 83.40it/s]
# Max det curr H: 55661776.573357314, Max det prev H: 50232502.89908569 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35171331.28119023, Max det prev H: 12523098.51114628 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27141893.049566403, Max det prev H: 8511949.951137403 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 3
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2048/10000 [00:23<01:25, 93.47it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2058/10000 [00:27<15:35,  8.49it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  22%|██▏       | 2246/10000 [00:30<07:16, 17.77it/s]
# Counter2: 2 == 2, crossing at 2237 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:57<00:00, 85.13it/s]
# Max det curr H: 55488746.116357274, Max det prev H: 22216465.28750041 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35540635.302508816, Max det prev H: 11646470.262018455 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26581592.314129412, Max det prev H: 7286489.561191487 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 4
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2047/10000 [00:23<01:22, 96.24it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2068/10000 [00:27<10:49, 12.21it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4110/10000 [00:54<07:34, 12.96it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:59<00:00, 83.43it/s]
# Max det curr H: 56148061.9825365, Max det prev H: 49142281.307793595 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35407362.03792642, Max det prev H: 11277940.714832956 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26696813.565418284, Max det prev H: 8139617.375977192 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 5
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2045/10000 [00:24<01:22, 96.54it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2063/10000 [00:28<12:03, 10.97it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  32%|███▏      | 3193/10000 [00:44<11:27,  9.90it/s]
# Counter2: 2 == 2, crossing at 3186 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:59<00:00, 83.64it/s]
# Max det curr H: 55751869.64368955, Max det prev H: 24947477.050252303 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35089373.10741018, Max det prev H: 11925668.944656583 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26927400.84049411, Max det prev H: 8556251.867963914 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 6
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2047/10000 [00:22<01:28, 89.58it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2067/10000 [00:26<11:22, 11.62it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4099/10000 [00:52<11:35,  8.48it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:59<00:00, 83.62it/s]
# Max det curr H: 56448926.8875287, Max det prev H: 47741944.5244286 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34211815.89377852, Max det prev H: 11623672.283185782 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26798670.864133902, Max det prev H: 8472106.823198138 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 7
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2040/10000 [00:20<01:08, 116.95it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2065/10000 [00:24<08:24, 15.72it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4104/10000 [00:49<10:24,  9.44it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [02:00<00:00, 83.00it/s]
# Max det curr H: 54566125.40604231, Max det prev H: 48074923.54196279 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35571322.46819409, Max det prev H: 11350137.712405758 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26856998.807742674, Max det prev H: 7551140.115261894 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 8
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2039/10000 [00:22<01:17, 103.13it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  20%|██        | 2050/10000 [00:26<14:17,  9.27it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  21%|██        | 2058/10000 [00:28<18:41,  7.08it/s]
# Counter2: 2 == 2, crossing at 2051 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:57<00:00, 85.30it/s]
# Max det curr H: 55137302.50741174, Max det prev H: 24134352.139970403 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34754335.63211794, Max det prev H: 11254263.094154457 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27996087.99883711, Max det prev H: 8064867.160906339 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 9
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2040/10000 [00:23<01:29, 88.81it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2060/10000 [00:28<12:37, 10.48it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4113/10000 [00:54<08:21, 11.73it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:59<00:00, 83.65it/s]
# Max det curr H: 56191528.680555806, Max det prev H: 48692834.34358254 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34389589.622511014, Max det prev H: 11253974.081544822 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26158619.66882061, Max det prev H: 8416630.231554382 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 10
# Lambda: 172.05721683334443 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 125.58630452612277 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Lambda: 102.35084837251196 private rs glinucb
# Count1 cutoff: 10, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2044/10000 [00:23<01:24, 93.80it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2062/10000 [00:27<12:02, 10.99it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4109/10000 [00:54<08:20, 11.78it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [02:06<00:00, 78.92it/s]
# Max det curr H: 54748903.372468665, Max det prev H: 48958101.23459858 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35096091.96963843, Max det prev H: 11696009.468974883 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26785603.297705486, Max det prev H: 7973718.180414016 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02

# %%
config = {"full_norm": True}
config['seed'] = 109832
config['model'] = 'Logistic'
config['theta_dim'] = 3
config['num_arms'] = 20
config['theta_norm'] = 3.5
config['horizon_length'] = 10000

env = GLMBandit(config=config)
print('Kappa =', env.kappa)
print('Theta =' , env.theta)
# Out:
# Calculating kappa...
# 100%|██████████| 10000/10000 [00:00<00:00, 52461.46it/s]
# Calculating kappa star...
# 100%|██████████| 10000/10000 [00:00<00:00, 52500.59it/s]
# Kappa = 35.00054767267832
# Theta = [0.51697808 3.19653397 1.32849698]

# %%
algo_names_list = ['RS-GLinUCB', 'EcoLog', 'GLOC', 'Private-GLM']
num_trials = 10

regret_dict = simulate_with_epsilon(num_trials, env, algo_names_list, 0.02, epsilon_arr = [4, 6,8], seed=109832)
with open('./Results/Extras/experiment_logistic_uniform_split_S_3_5.pickle', 'wb') as f:
    pickle.dump(regret_dict, f)
plot_regret(regret_dict, env.T, './Results/Extras/Logistic_Regret_S_3_5.png')
##plot_regret(regret_dict, env.T, './Results/Logistic_Regret.png')
# Out:
# Simulating trial 1
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2035/10000 [00:14<00:48, 163.65it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2068/10000 [00:16<05:17, 24.99it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4120/10000 [00:32<04:06, 23.88it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:10<00:00, 141.29it/s]
# Max det curr H: 53902469.120067954, Max det prev H: 49947007.386238605 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 33612717.23485565, Max det prev H: 11012364.946658421 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26383440.774346355, Max det prev H: 8368105.632655533 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 2
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2034/10000 [00:13<00:47, 167.25it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2068/10000 [00:16<05:05, 25.96it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4123/10000 [00:31<03:46, 25.90it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:08<00:00, 146.84it/s]
# Max det curr H: 55112790.51220548, Max det prev H: 50050182.23373417 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35067737.24562049, Max det prev H: 12528860.615540152 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26999537.275135078, Max det prev H: 8473545.961561475 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 3
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2037/10000 [00:13<00:47, 167.35it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2066/10000 [00:16<05:34, 23.75it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  23%|██▎       | 2269/10000 [00:18<03:07, 41.29it/s]
# Counter2: 2 == 2, crossing at 2237 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:07<00:00, 148.67it/s]
# Max det curr H: 55236389.597180195, Max det prev H: 22146896.207253896 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34611056.00320511, Max det prev H: 11546663.564184824 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26490850.375182204, Max det prev H: 7238436.6338223405 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 4
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2041/10000 [00:13<00:48, 162.70it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2075/10000 [00:16<05:12, 25.37it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████▏     | 4128/10000 [00:31<03:45, 26.07it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:08<00:00, 145.33it/s]
# Max det curr H: 55291509.22934911, Max det prev H: 48653200.611948535 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35072635.42446173, Max det prev H: 11212214.298020545 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26718025.443273216, Max det prev H: 8122789.875689981 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 5
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2049/10000 [00:13<00:48, 165.39it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2066/10000 [00:16<06:58, 18.96it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  32%|███▏      | 3203/10000 [00:25<03:35, 31.54it/s]
# Counter2: 2 == 2, crossing at 3186 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:09<00:00, 143.52it/s]
# Max det curr H: 55370549.27269504, Max det prev H: 24893860.273056187 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34638106.54266165, Max det prev H: 11843515.297082232 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26947613.795816004, Max det prev H: 8533110.456113348 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 6
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2049/10000 [00:13<00:49, 161.93it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2066/10000 [00:16<07:01, 18.81it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4124/10000 [00:32<03:54, 25.07it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:11<00:00, 139.93it/s]
# Max det curr H: 55887136.415891126, Max det prev H: 47333526.68545078 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34006827.109496914, Max det prev H: 11586508.54558105 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26371990.055503868, Max det prev H: 8393821.778807068 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 7
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2035/10000 [00:14<00:53, 149.49it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2068/10000 [00:17<05:23, 24.54it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4122/10000 [00:32<04:05, 23.96it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:12<00:00, 138.70it/s]
# Max det curr H: 54015610.3826165, Max det prev H: 47451291.97339129 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34761232.56001299, Max det prev H: 11298703.796387998 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26386877.96933857, Max det prev H: 7550043.085700714 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 8
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2047/10000 [00:14<00:49, 160.70it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  21%|██        | 2081/10000 [00:18<07:30, 17.57it/s]
# Counter2: 2 == 2, crossing at 2051 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:10<00:00, 141.19it/s]
# Max det curr H: 54510084.29323304, Max det prev H: 24093169.13050329 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34614471.16402356, Max det prev H: 11221735.224391166 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27476802.90590594, Max det prev H: 8014777.267573204 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 9
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2040/10000 [00:14<00:50, 158.75it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2072/10000 [00:17<05:37, 23.46it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4124/10000 [00:33<04:06, 23.80it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:12<00:00, 137.95it/s]
# Max det curr H: 56068393.36343493, Max det prev H: 48214230.449968755 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34204519.52345691, Max det prev H: 11164418.903452963 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26354686.57629935, Max det prev H: 8396698.775381131 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 10
# Lambda: 172.05721683192922 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 125.58630452517929 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Lambda: 102.35084837180435 private rs glinucb
# Count1 cutoff: 23, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2043/10000 [00:14<00:50, 156.94it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2075/10000 [00:17<05:33, 23.76it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4115/10000 [00:33<04:08, 23.72it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:12<00:00, 138.67it/s]
# Max det curr H: 54277683.57169042, Max det prev H: 48771366.931347154 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34086587.506466664, Max det prev H: 11700791.50877896 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26447074.208919957, Max det prev H: 7941750.599165284 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02

# %%
config = {"full_norm": True}
config['seed'] = 109832
config['model'] = 'Logistic'
config['theta_dim'] = 3
config['num_arms'] = 20
config['theta_norm'] = 4.0
config['horizon_length'] = 10000

env = GLMBandit(config=config)
print('Kappa =', env.kappa)
print('Theta =' , env.theta)
# Out:
# Calculating kappa...
# 100%|██████████| 10000/10000 [00:00<00:00, 38316.81it/s]
# Calculating kappa star...
# 100%|██████████| 10000/10000 [00:00<00:00, 38263.16it/s]
# Kappa = 56.34298486057823
# Theta = [0.59083209 3.65318168 1.51828226]

# %%
algo_names_list = ['RS-GLinUCB', 'EcoLog', 'GLOC', 'Private-GLM']
num_trials = 10

regret_dict = simulate_with_epsilon(num_trials, env, algo_names_list, 0.02, epsilon_arr = [4, 6,8], seed=109832)
with open('./Results/Extras/experiment_logistic_uniform_split_S_4_0.pickle', 'wb') as f:
    pickle.dump(regret_dict, f)
plot_regret(regret_dict, env.T, './Results/Extras/Logistic_Regret_S_4_0.png')
##plot_regret(regret_dict, env.T, './Results/Logistic_Regret.png')
# Out:
# Simulating trial 1
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2045/10000 [00:23<01:38, 80.63it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2064/10000 [00:27<12:26, 10.63it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4115/10000 [00:55<08:52, 11.04it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [02:06<00:00, 78.80it/s]
# Max det curr H: 53770446.502960905, Max det prev H: 50031774.8402859 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 33498255.315859813, Max det prev H: 10972523.46766002 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26542978.41759239, Max det prev H: 8348062.763662224 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 2
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2049/10000 [00:27<01:21, 97.54it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2059/10000 [00:30<14:30,  9.12it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4107/10000 [00:58<09:34, 10.25it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:55<00:00, 86.30it/s]
# Max det curr H: 54969556.91317267, Max det prev H: 49938171.83211372 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 35012144.65262037, Max det prev H: 12491125.621193543 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26691671.500729818, Max det prev H: 8456733.412204916 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 3
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2040/10000 [00:16<00:57, 138.56it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2068/10000 [00:19<06:34, 20.09it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  23%|██▎       | 2348/10000 [00:22<03:26, 37.04it/s]
# Counter2: 2 == 2, crossing at 2327 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:17<00:00, 128.61it/s]
# Max det curr H: 55005197.19041531, Max det prev H: 22295079.172553524 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34891994.90761202, Max det prev H: 11492491.040514862 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26611789.556703515, Max det prev H: 7203324.562951495 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 4
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2047/10000 [00:17<01:20, 99.38it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2072/10000 [00:21<08:51, 14.93it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4117/10000 [00:39<04:46, 20.54it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:32<00:00, 107.55it/s]
# Max det curr H: 55278099.22094191, Max det prev H: 48618828.90988699 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34930797.263291396, Max det prev H: 11199473.532377632 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26989676.95620753, Max det prev H: 8081488.701145858 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 5
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2036/10000 [00:18<00:54, 145.65it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2051/10000 [00:21<08:27, 15.66it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  32%|███▏      | 3197/10000 [00:32<04:52, 23.29it/s]
# Counter2: 2 == 2, crossing at 3186 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:23<00:00, 119.56it/s]
# Max det curr H: 55125551.237853006, Max det prev H: 24849149.899688356 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34293107.04359718, Max det prev H: 11747220.277504943 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26974543.901793815, Max det prev H: 8534853.874759149 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 6
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2042/10000 [00:15<00:52, 150.83it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2071/10000 [00:18<05:51, 22.57it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4120/10000 [00:35<04:03, 24.12it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:18<00:00, 126.70it/s]
# Max det curr H: 55617683.841774695, Max det prev H: 47247033.83707352 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 33626613.3480821, Max det prev H: 11529614.340482032 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26138125.627298206, Max det prev H: 8362107.195041122 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 7
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2036/10000 [00:14<00:51, 155.30it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2068/10000 [00:17<05:49, 22.71it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4116/10000 [00:34<04:15, 23.00it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:17<00:00, 129.58it/s]
# Max det curr H: 54260806.46245551, Max det prev H: 47800656.39873113 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 34436863.32228937, Max det prev H: 11249846.723993646 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26037498.007182013, Max det prev H: 7513155.548982999 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 8
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2048/10000 [00:15<00:52, 152.82it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  21%|██        | 2080/10000 [00:19<08:17, 15.92it/s]
# Counter2: 2 == 2, crossing at 2051 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:16<00:00, 130.73it/s]
# Max det curr H: 54485076.943975754, Max det prev H: 24042590.910224777 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 33969359.830520704, Max det prev H: 11178312.540928515 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 27376108.439343978, Max det prev H: 7984640.041635388 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 9
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2040/10000 [00:14<00:51, 154.31it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2072/10000 [00:17<05:42, 23.13it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████▏     | 4128/10000 [00:34<04:05, 23.88it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:17<00:00, 128.59it/s]
# Max det curr H: 55851287.24956818, Max det prev H: 48079689.34671126 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 33672530.41351356, Max det prev H: 11114519.956785263 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26416634.908098746, Max det prev H: 8374128.720162238 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 10
# Lambda: 172.05721683029628 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 125.58630452409068 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Lambda: 102.35084837098788 private rs glinucb
# Count1 cutoff: 49, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  20%|██        | 2041/10000 [00:15<00:52, 150.79it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  21%|██        | 2074/10000 [00:18<05:21, 24.68it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 8 delta 0.02
#  41%|████      | 4117/10000 [00:35<06:03, 16.17it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:17<00:00, 129.42it/s]
# Max det curr H: 54317613.4769206, Max det prev H: 48741285.22337105 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 33472435.553585015, Max det prev H: 11649099.851091543 epsilon 6 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 26413381.344189066, Max det prev H: 7941473.468619745 epsilon 8 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 8 delta 0.02

# %%
config = {"full_norm": True}
config['seed'] = 109832
config['model'] = 'Logistic'
config['theta_dim'] = 3
config['num_arms'] = 20
config['theta_norm'] = 4.5
config['horizon_length'] = 10000

env = GLMBandit(config=config)
print('Kappa =', env.kappa)
print('Theta =' , env.theta)
# Out:
# Calculating kappa...
# 100%|██████████| 10000/10000 [00:00<00:00, 51724.76it/s]
# Calculating kappa star...
# 100%|██████████| 10000/10000 [00:00<00:00, 53179.36it/s]
# Kappa = 91.52103598069573
# Theta = [0.6646861  4.1098294  1.70806754]

# %%
algo_names_list = ['RS-GLinUCB', 'EcoLog', 'GLOC', 'Private-GLM']
num_trials = 5

regret_dict = simulate_with_epsilon(num_trials, env, algo_names_list, 0.02, epsilon_arr = [4, 6,8], seed=109832)
with open('./Results/Extras/experiment_logistic_uniform_split_S_4_5.pickle', 'wb') as f:
    pickle.dump(regret_dict, f)
plot_regret(regret_dict, env.T, './Results/Extras/Logistic_Regret_S_4_5.png')
##plot_regret(regret_dict, env.T, './Results/Logistic_Regret.png')
# Out:
# Simulating trial 1
# Lambda: 172.05721682844558 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 125.58630452285686 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 102.35084837006252 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  41%|████      | 4123/10000 [00:30<03:51, 25.40it/s]
# Counter2: 2 == 2, crossing at 4098 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:14<00:00, 133.74it/s]
# Max det curr H: 53826796.97226754, Max det prev H: 49997896.0678427 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 5923089.720941835, Max det prev H: 3979180.4793040506 epsilon 6 delta 0.02
# Counter1 final: 3, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 1442143.270661545, Max det prev H: 1072196.3894550304 epsilon 8 delta 0.02
# Counter1 final: 15, Counter2 final: 0 epsilon 8 delta 0.02
# Simulating trial 2
# Lambda: 172.05721682844558 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 125.58630452285686 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 102.35084837006252 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
# 100%|██████████| 10000/10000 [01:24<00:00, 117.86it/s]
# Max det curr H: 8943485.770833693, Max det prev H: 5093527.797408495 epsilon 4 delta 0.02
# Counter1 final: 1, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 4927310.364605994, Max det prev H: 4103973.76518975 epsilon 6 delta 0.02
# Counter1 final: 8, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 1460565.8309629897, Max det prev H: 1072196.3894550304 epsilon 8 delta 0.02
# Counter1 final: 19, Counter2 final: 0 epsilon 8 delta 0.02
# Simulating trial 3
# Lambda: 172.05721682844558 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 125.58630452285686 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 102.35084837006252 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  22%|██▏       | 2249/10000 [00:24<05:30, 23.43it/s]
# Counter2: 2 == 2, crossing at 2237 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:32<00:00, 107.99it/s]
# Max det curr H: 54752885.80832228, Max det prev H: 22147221.67213096 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 2583125.757014638, Max det prev H: 1980737.1334254197 epsilon 6 delta 0.02
# Counter1 final: 1, Counter2 final: 0 epsilon 6 delta 0.02
# Max det curr H: 1343676.4937757829, Max det prev H: 1072196.3894550304 epsilon 8 delta 0.02
# Counter1 final: 10, Counter2 final: 0 epsilon 8 delta 0.02
# Simulating trial 4
# Lambda: 172.05721682844558 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 125.58630452285686 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 102.35084837006252 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  21%|██        | 2074/10000 [00:19<04:00, 32.97it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  62%|██████▏   | 6230/10000 [01:05<05:53, 10.66it/s]
# Counter2: 2 == 2, crossing at 6215 epsilon 8 delta 0.02
# 100%|██████████| 10000/10000 [01:40<00:00, 99.75it/s]
# Max det curr H: 23780876.34839623, Max det prev H: 13065772.977736108 epsilon 4 delta 0.02
# Counter1 final: 3, Counter2 final: 1 epsilon 4 delta 0.02
# Max det curr H: 34910061.27659565, Max det prev H: 11203802.904567907 epsilon 6 delta 0.02
# Counter1 final: 1, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 10976724.327394001, Max det prev H: 4522034.219514214 epsilon 8 delta 0.02
# Counter1 final: 39, Counter2 final: 2 epsilon 8 delta 0.02
# Simulating trial 5
# Lambda: 172.05721682844558 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 125.58630452285686 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Lambda: 102.35084837006252 private rs glinucb
# Count1 cutoff: 100, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  21%|██        | 2060/10000 [00:21<07:20, 18.03it/s]
# Counter2: 2 == 2, crossing at 2050 epsilon 6 delta 0.02
#  32%|███▏      | 3207/10000 [00:33<06:00, 18.83it/s]
# Counter2: 2 == 2, crossing at 3186 epsilon 4 delta 0.02
# 100%|██████████| 10000/10000 [01:35<00:00, 104.93it/s]
# Max det curr H: 54980327.48130865, Max det prev H: 24852316.71004927 epsilon 4 delta 0.02
# Counter1 final: 0, Counter2 final: 2 epsilon 4 delta 0.02
# Max det curr H: 9230446.142597945, Max det prev H: 8604996.846466728 epsilon 6 delta 0.02
# Counter1 final: 8, Counter2 final: 2 epsilon 6 delta 0.02
# Max det curr H: 1387718.5437948166, Max det prev H: 1072196.3894550304 epsilon 8 delta 0.02
# Counter1 final: 26, Counter2 final: 0 epsilon 8 delta 0.02

# %%
config = {"full_norm": True}
config['seed'] = 109832
config['model'] = 'Logistic'
config['theta_dim'] = 3
config['num_arms'] = 20
config['theta_norm'] = 5.0
config['horizon_length'] = 10000

env = GLMBandit(config=config)
print('Kappa =', env.kappa)
print('Theta =' , env.theta)
# Out:
# Calculating kappa...
# 100%|██████████| 10000/10000 [00:00<00:00, 38164.73it/s]
# Calculating kappa star...
# 100%|██████████| 10000/10000 [00:00<00:00, 38468.63it/s]
# Kappa = 149.49096163289423
# Theta = [0.73854011 4.56647711 1.89785282]

# %%
algo_names_list = ['RS-GLinUCB', 'EcoLog', 'GLOC', 'Private-GLM']
num_trials = 10

regret_dict = simulate_with_epsilon(num_trials, env, algo_names_list, 0.02, epsilon_arr = [4, 6,8], seed=109832)
with open('./Results/Extras/experiment_logistic_uniform_split_S_5_0.pickle', 'wb') as f:
    pickle.dump(regret_dict, f)
plot_regret(regret_dict, env.T, './Results/Extras/Logistic_Regret_S_5_0.png')
##plot_regret(regret_dict, env.T, './Results/Logistic_Regret.png')
# Out:
# Simulating trial 1
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#   0%|          | 0/10000 [00:00<?, ?it/s]/Users/sahasrajitsarmasarkar/Downloads/AiStats_appendix/Code/glmbanditexp/utils/utils.py:229: RuntimeWarning: divide by zero encountered in log
#   return - np.sum(Y * np.log(sigmoid(np.dot(X, theta))) + (1 - Y) * np.log(1 - sigmoid(np.dot(X, theta)))) + lmbda * np.sum(np.square(theta))
#   0%|          | 2/10000 [00:00<15:25, 10.80it/s]/Users/sahasrajitsarmasarkar/Downloads/AiStats_appendix/Code/glmbanditexp/utils/utils.py:229: RuntimeWarning: invalid value encountered in multiply
#   return - np.sum(Y * np.log(sigmoid(np.dot(X, theta))) + (1 - Y) * np.log(1 - sigmoid(np.dot(X, theta)))) + lmbda * np.sum(np.square(theta))
#  83%|████████▎ | 8257/10000 [02:18<01:06, 26.11it/s]
# Counter1: 203 == 203, crossing at 8247 epsilon 8 delta 0.02
#  92%|█████████▏| 9204/10000 [02:38<00:13, 58.59it/s]
# Counter1: 203 == 203, crossing at 9189 epsilon 6 delta 0.02
# 100%|██████████| 10000/10000 [02:49<00:00, 58.95it/s]
# Max det curr H: 6240034.09691781, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 48, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 5009513.146605803, Max det prev H: 4091204.8080308833 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 2623765.7931301403, Max det prev H: 2186379.0053138034 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02
# Simulating trial 2
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  83%|████████▎ | 8287/10000 [02:12<03:55,  7.26it/s]
# Counter1: 203 == 203, crossing at 8284 epsilon 8 delta 0.02
#  83%|████████▎ | 8328/10000 [02:16<01:13, 22.77it/s]
# Counter1: 203 == 203, crossing at 8319 epsilon 6 delta 0.02
# 100%|██████████| 10000/10000 [02:34<00:00, 64.88it/s]
# Max det curr H: 6445409.78676806, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 49, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 7045909.125045434, Max det prev H: 4066193.0960018164 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 3348142.066592962, Max det prev H: 2178604.0296304594 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02
# Simulating trial 3
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  83%|████████▎ | 8252/10000 [02:13<07:49,  3.72it/s]
# Counter1: 203 == 203, crossing at 8252 epsilon 8 delta 0.02
#  99%|█████████▉| 9944/10000 [02:46<00:01, 30.99it/s]
# Counter1: 203 == 203, crossing at 9939 epsilon 6 delta 0.02
# 100%|██████████| 10000/10000 [02:47<00:00, 59.75it/s]
# Max det curr H: 6420481.135220389, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 82, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 5077974.449151224, Max det prev H: 4415774.517649359 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 4026446.9058652013, Max det prev H: 3406525.092903129 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02
# Simulating trial 4
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  82%|████████▏ | 8242/10000 [02:05<02:01, 14.53it/s]
# Counter1: 203 == 203, crossing at 8235 epsilon 8 delta 0.02
#  92%|█████████▏| 9212/10000 [02:25<00:22, 35.21it/s]
# Counter1: 203 == 203, crossing at 9202 epsilon 6 delta 0.02
# 100%|██████████| 10000/10000 [02:34<00:00, 64.65it/s]
# Max det curr H: 7038706.517800237, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 88, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 5658838.60399987, Max det prev H: 4129060.7889101617 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 2867460.096150781, Max det prev H: 2192049.6375073297 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02
# Simulating trial 5
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  82%|████████▏ | 8239/10000 [02:05<01:53, 15.51it/s]
# Counter1: 203 == 203, crossing at 8229 epsilon 8 delta 0.02
#  84%|████████▍ | 8419/10000 [02:13<00:49, 32.22it/s]
# Counter1: 203 == 203, crossing at 8410 epsilon 6 delta 0.02
# 100%|██████████| 10000/10000 [02:32<00:00, 65.70it/s]
# Max det curr H: 6963332.255902844, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 78, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 5889004.793044799, Max det prev H: 3970407.5848223865 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 3024649.1252508187, Max det prev H: 2156724.035004994 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02
# Simulating trial 6
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#   3%|▎         | 261/10000 [00:12<04:05, 39.63it/s]/Users/sahasrajitsarmasarkar/Downloads/AiStats_appendix/Code/glmbanditexp/utils/utils.py:216: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-x))
#  83%|████████▎ | 8285/10000 [01:57<03:45,  7.62it/s]
# Counter1: 203 == 203, crossing at 8285 epsilon 6 delta 0.02
#  84%|████████▍ | 8379/10000 [02:00<00:26, 60.73it/s]
# Counter1: 203 == 203, crossing at 8362 epsilon 8 delta 0.02
# 100%|██████████| 10000/10000 [02:13<00:00, 74.79it/s]
# Max det curr H: 7509695.437255178, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 83, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 5293836.131795381, Max det prev H: 3986807.9098198963 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 2574596.379431396, Max det prev H: 2147837.4957953803 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02
# Simulating trial 7
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  83%|████████▎ | 8312/10000 [01:29<00:41, 40.56it/s]
# Counter1: 203 == 203, crossing at 8296 epsilon 8 delta 0.02
#  87%|████████▋ | 8671/10000 [01:36<00:20, 64.56it/s]
# Counter1: 203 == 203, crossing at 8650 epsilon 6 delta 0.02
# 100%|██████████| 10000/10000 [01:45<00:00, 94.43it/s]
# Max det curr H: 7386949.295719298, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 73, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 6152379.1107709985, Max det prev H: 5444692.390739151 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 3115519.831170517, Max det prev H: 2176006.244729528 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02
# Simulating trial 8
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  83%|████████▎ | 8251/10000 [01:28<02:17, 12.72it/s]
# Counter1: 203 == 203, crossing at 8248 epsilon 8 delta 0.02
#  85%|████████▌ | 8518/10000 [01:35<00:19, 75.28it/s]
# Counter1: 203 == 203, crossing at 8504 epsilon 6 delta 0.02
# 100%|██████████| 10000/10000 [01:47<00:00, 93.27it/s]
# Max det curr H: 6535989.299105825, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 73, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 5697649.598987757, Max det prev H: 3973238.21448159 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 4055270.04376682, Max det prev H: 2178320.883009946 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02
# Simulating trial 9
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  83%|████████▎ | 8341/10000 [01:30<02:04, 13.34it/s]
# Counter1: 203 == 203, crossing at 8340 epsilon 8 delta 0.02
#  86%|████████▌ | 8604/10000 [01:35<00:16, 84.46it/s]
# Counter1: 203 == 203, crossing at 8581 epsilon 6 delta 0.02
# 100%|██████████| 10000/10000 [01:45<00:00, 94.50it/s]
# Max det curr H: 6778933.877101102, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 60, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 5967735.674533596, Max det prev H: 4013988.3147247266 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 2748040.881655833, Max det prev H: 2197489.5292788995 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02
# Simulating trial 10
# Lambda: 172.05721682637719 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 125.58630452147796 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Lambda: 102.35084836902834 private rs glinucb
# Count1 cutoff: 203, Count2 cutoff: 2
# Algorithm mapping:
#   Index 0: RS-GLinUCB (Sawarni et al. 2024) -> ε=None
#   Index 1: ECOLog (Faury et al. 2022) -> ε=None
#   Index 2: GLOC (Jun et al. 2017) -> ε=None
#   Index 3: Private-GLM (This work) -> ε=4
#   Index 4: Private-GLM (This work) -> ε=6
#   Index 5: Private-GLM (This work) -> ε=8
#  82%|████████▏ | 8214/10000 [01:28<02:27, 12.15it/s]
# Counter1: 203 == 203, crossing at 8214 epsilon 8 delta 0.02
#  83%|████████▎ | 8319/10000 [01:34<00:39, 42.13it/s]
# Counter1: 203 == 203, crossing at 8301 epsilon 6 delta 0.02
# 100%|██████████| 10000/10000 [01:46<00:00, 94.08it/s]
# Max det curr H: 6466881.5182663305, Max det prev H: 5093527.797224795 epsilon 4 delta 0.02
# Counter1 final: 60, Counter2 final: 0 epsilon 4 delta 0.02
# Max det curr H: 5563931.726212728, Max det prev H: 4935534.30253547 epsilon 6 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 6 delta 0.02
# Max det curr H: 2389711.3818102637, Max det prev H: 2227021.5463177375 epsilon 8 delta 0.02
# Counter1 final: 203, Counter2 final: 1 epsilon 8 delta 0.02

# %%
config = {"full_norm": True}
config['seed'] = 109832
config['model'] = 'Logistic'
config['theta_dim'] = 3
config['num_arms'] = 20
config['theta_norm'] = 5.5
config['horizon_length'] = 10000

env = GLMBandit(config=config)
print('Kappa =', env.kappa)
print('Theta =' , env.theta)
# Out:
# Calculating kappa...
# 100%|██████████| 10000/10000 [00:00<00:00, 50364.61it/s]
# Calculating kappa star...
# 100%|██████████| 10000/10000 [00:00<00:00, 52498.16it/s]
# Kappa = 245.01178753246853
# Theta = [0.81239412 5.02312482 2.08763811]
